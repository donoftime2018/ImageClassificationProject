# %%
# !pip install scipy --upgrade --quiet
import scipy
print("SciPy version:", scipy.__version__)
# Out:
# SciPy version: 1.16.3
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras import layers
from tensorflow.keras.applications import MobileNetV2  # Smaller than EfficientNet
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %%
IMG_SIZE = 180

datagen_train = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)
datagen_test = ImageDataGenerator(rescale=1./255)

train_set = datagen_train.flow_from_directory(
    "../dataset/pokemon/train",
    target_size=(IMG_SIZE, IMG_SIZE),
    class_mode='categorical',
    batch_size=32
)

test_set = datagen_test.flow_from_directory(
    "../dataset/pokemon/validation",
    target_size=(IMG_SIZE, IMG_SIZE),
    class_mode='categorical',
    batch_size=32
)

print("Train samples:", train_set.samples)
print("Val samples:", test_set.samples)
print("Classes:", len(train_set.class_indices))
# Out:
# Found 4978 images belonging to 150 classes.
# Found 1842 images belonging to 150 classes.
# Train samples: 4978
# Val samples: 1842
# Classes: 150

# %%
base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False

inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(len(train_set.class_indices), activation='softmax')(x)

model = Model(inputs, outputs)
model.summary()
# Out:
# C:\Users\91916\AppData\Local\Temp\ipykernel_20832\2035857503.py:1: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ mobilenetv2_1.00_224 (Functional)    │ (None, 6, 6, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         163,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 150)                 │          19,350 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,441,302 (9.31 MB)
#  Trainable params: 183,318 (716.09 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
callbacks = [
    EarlyStopping(monitor='val_accuracy', patience=8, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=4, min_lr=1e-7, verbose=1)
]

# %%
model.compile(optimizer=Adam(0.001), loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(
    train_set,
    validation_data=test_set,
    epochs=20,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 130s 800ms/step - accuracy: 0.0237 - loss: 4.9413 - val_accuracy: 0.0782 - val_loss: 4.6224 - learning_rate: 0.0010
# Epoch 2/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 137s 876ms/step - accuracy: 0.1107 - loss: 4.2350 - val_accuracy: 0.2557 - val_loss: 3.4823 - learning_rate: 0.0010
# Epoch 3/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.2290 - loss: 3.4090 - val_accuracy: 0.4359 - val_loss: 2.6587 - learning_rate: 0.0010
# Epoch 4/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 144s 925ms/step - accuracy: 0.3146 - loss: 2.8932 - val_accuracy: 0.5201 - val_loss: 2.1782 - learning_rate: 0.0010
# Epoch 5/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 147s 938ms/step - accuracy: 0.3777 - loss: 2.5336 - val_accuracy: 0.5429 - val_loss: 1.9967 - learning_rate: 0.0010
# Epoch 6/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 124s 796ms/step - accuracy: 0.4257 - loss: 2.3010 - val_accuracy: 0.6021 - val_loss: 1.7794 - learning_rate: 0.0010
# Epoch 7/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 89s 568ms/step - accuracy: 0.4526 - loss: 2.1328 - val_accuracy: 0.6303 - val_loss: 1.5971 - learning_rate: 0.0010
# Epoch 8/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 117s 741ms/step - accuracy: 0.4753 - loss: 2.0210 - val_accuracy: 0.6439 - val_loss: 1.5127 - learning_rate: 0.0010
# Epoch 9/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 108s 690ms/step - accuracy: 0.5110 - loss: 1.8767 - val_accuracy: 0.6531 - val_loss: 1.4339 - learning_rate: 0.0010
# Epoch 10/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 84s 538ms/step - accuracy: 0.5185 - loss: 1.8297 - val_accuracy: 0.6547 - val_loss: 1.3957 - learning_rate: 0.0010
# Epoch 11/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 93s 596ms/step - accuracy: 0.5295 - loss: 1.7899 - val_accuracy: 0.6705 - val_loss: 1.3602 - learning_rate: 0.0010
# Epoch 12/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 122s 781ms/step - accuracy: 0.5522 - loss: 1.7015 - val_accuracy: 0.6732 - val_loss: 1.3104 - learning_rate: 0.0010
# Epoch 13/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 108s 690ms/step - accuracy: 0.5599 - loss: 1.6487 - val_accuracy: 0.6851 - val_loss: 1.3002 - learning_rate: 0.0010
# Epoch 14/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 139s 679ms/step - accuracy: 0.5741 - loss: 1.5983 - val_accuracy: 0.6743 - val_loss: 1.2709 - learning_rate: 0.0010
# Epoch 15/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 187s 969ms/step - accuracy: 0.5765 - loss: 1.5783 - val_accuracy: 0.6906 - val_loss: 1.2492 - learning_rate: 0.0010
# Epoch 16/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 123s 788ms/step - accuracy: 0.5783 - loss: 1.5325 - val_accuracy: 0.6808 - val_loss: 1.2471 - learning_rate: 0.0010
# Epoch 17/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 85s 542ms/step - accuracy: 0.5888 - loss: 1.5087 - val_accuracy: 0.6900 - val_loss: 1.2006 - learning_rate: 0.0010
# Epoch 18/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 104s 668ms/step - accuracy: 0.6063 - loss: 1.4669 - val_accuracy: 0.6998 - val_loss: 1.2198 - learning_rate: 0.0010
# Epoch 19/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 87s 559ms/step - accuracy: 0.6055 - loss: 1.4380 - val_accuracy: 0.6971 - val_loss: 1.1697 - learning_rate: 0.0010
# Epoch 20/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 99s 635ms/step - accuracy: 0.6179 - loss: 1.4389 - val_accuracy: 0.7090 - val_loss: 1.1410 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 20.

# %%
# Best validation accuracy during training
best_val_acc = max(history.history['val_accuracy'])
print("Best val_accuracy during training:", best_val_acc)

# Final evaluation on validation set
val_loss, val_acc = model.evaluate(test_set)
print("Final validation loss:", val_loss)
print("Final validation accuracy:", val_acc)

# Also print training accuracy for comparison
best_train_acc = max(history.history['accuracy'])
print("Best training accuracy:", best_train_acc)
# Out:
# Best val_accuracy during training: 0.709011971950531
# 58/58 ━━━━━━━━━━━━━━━━━━━━